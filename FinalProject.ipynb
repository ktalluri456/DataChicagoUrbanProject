# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.use('seaborn-colorblind')

# %%
Chicagourb = pd.read_csv('CHIC917URN.csv')
Chicagourb.head()
# Out:
#          DATE  CHIC917URN
# 0  1990-01-01         6.6
# 1  1990-02-01         6.5
# 2  1990-03-01         6.3
# 3  1990-04-01         6.3
# 4  1990-05-01         6.1

# %%
Chicagourb.shape
# Out:
# (354, 2)

# %%
Nationalurb = pd.read_csv('UNRATE.csv')
Nationalurb.head()
# Out:
#      DATE  UNRATE
# 0  1/1/90     5.4
# 1  2/1/90     5.3
# 2  3/1/90     5.2
# 3  4/1/90     5.4
# 4  5/1/90     5.4

# %%
Unemployment_Average = Chicagourb.groupby('DATE').mean()
Unemployment_Average.iloc[0]
print(type(Unemployment_Average.iloc[0]))
Jan = Unemployment_Average.iloc[0]
Feb = Unemployment_Average.iloc[1]
Mar = Unemployment_Average.iloc[2]
Apr = Unemployment_Average.iloc[3]
May = Unemployment_Average.iloc[4]
Jun = Unemployment_Average.iloc[5]
Jul = Unemployment_Average.iloc[6]
Aug = Unemployment_Average.iloc[7]
Sep = Unemployment_Average.iloc[8]
Oct = Unemployment_Average.iloc[9]
Nov = Unemployment_Average.iloc[10]
Dec = Unemployment_Average.iloc[11]
# Out:
# <class 'pandas.core.series.Series'>

# %%
Population = pd.DataFrame({'Unemployment_Average': [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]})
Population
# Out:
#                                  Unemployment_Average
# 0   CHIC917URN    6.6
# Name: 1990-01-01, dtype: flo...
# 1   CHIC917URN    6.5
# Name: 1990-02-01, dtype: flo...
# 2   CHIC917URN    6.3
# Name: 1990-03-01, dtype: flo...
# 3   CHIC917URN    6.3
# Name: 1990-04-01, dtype: flo...
# 4   CHIC917URN    6.1
# Name: 1990-05-01, dtype: flo...
# 5   CHIC917URN    6.2
# Name: 1990-06-01, dtype: flo...
# 6   CHIC917URN    6.3
# Name: 1990-07-01, dtype: flo...
# 7   CHIC917URN    6.4
# Name: 1990-08-01, dtype: flo...
# 8   CHIC917URN    6.3
# Name: 1990-09-01, dtype: flo...
# 9   CHIC917URN    6.0
# Name: 1990-10-01, dtype: flo...
# 10  CHIC917URN    5.9
# Name: 1990-11-01, dtype: flo...
# 11  CHIC917URN    6.2
# Name: 1990-12-01, dtype: flo...

# %%
Unemployment_National = Nationalurb.groupby('DATE').mean()
Jan = Unemployment_National.iloc[0]
Feb = Unemployment_National.iloc[1]
Mar = Unemployment_National.iloc[2]
Apr = Unemployment_National.iloc[3]
May = Unemployment_National.iloc[4]
Jun = Unemployment_National.iloc[5]
Jul = Unemployment_National.iloc[6]
Aug = Unemployment_National.iloc[7]
Sep = Unemployment_National.iloc[8]
Oct = Unemployment_National.iloc[9]
Nov = Unemployment_National.iloc[10]
Dec = Unemployment_National.iloc[11]

# %%
Population['Unemployment_National'] = [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
Population
# Out:
#                                  Unemployment_Average  \
# 0   CHIC917URN    6.6
# Name: 1990-01-01, dtype: flo...
# 1   CHIC917URN    6.5
# Name: 1990-02-01, dtype: flo...
# 2   CHIC917URN    6.3
# Name: 1990-03-01, dtype: flo...
# 3   CHIC917URN    6.3
# Name: 1990-04-01, dtype: flo...
# 4   CHIC917URN    6.1
# Name: 1990-05-01, dtype: flo...
# 5   CHIC917URN    6.2
# Name: 1990-06-01, dtype: flo...
# 6   CHIC917URN    6.3
# Name: 1990-07-01, dtype: flo...
# 7   CHIC917URN    6.4
# Name: 1990-08-01, dtype: flo...
# 8   CHIC917URN    6.3
# Name: 1990-09-01, dtype: flo...
# 9   CHIC917URN    6.0
# Name: 1990-10-01, dtype: flo...
# 10  CHIC917URN    5.9
# Name: 1990-11-01, dtype: flo...
# 11  CHIC917URN    6.2
# Name: 1990-12-01, dtype: flo...
#
#                          Unemployment_National
# 0   UNRATE    4.0
# Name: 1/1/00, dtype: float64
# 1   UNRATE    4.2
# Name: 1/1/01, dtype: float64
# 2   UNRATE    5.7
# Name: 1/1/02, dtype: float64
# 3   UNRATE    5.8
# Name: 1/1/03, dtype: float64
# 4   UNRATE    5.7
# Name: 1/1/04, dtype: float64
# 5   UNRATE    5.3
# Name: 1/1/05, dtype: float64
# 6   UNRATE    4.7
# Name: 1/1/06, dtype: float64
# 7   UNRATE    4.6
# Name: 1/1/07, dtype: float64
# 8   UNRATE    5.0
# Name: 1/1/08, dtype: float64
# 9   UNRATE    7.8
# Name: 1/1/09, dtype: float64
# 10  UNRATE    9.8
# Name: 1/1/10, dtype: float64
# 11  UNRATE    9.1
# Name: 1/1/11, dtype: float64

# %%
Population.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Population
# Out:
#                                   Unemployment_Average  \
# Jan  CHIC917URN    6.6
# Name: 1990-01-01, dtype: flo...
# Feb  CHIC917URN    6.5
# Name: 1990-02-01, dtype: flo...
# Mar  CHIC917URN    6.3
# Name: 1990-03-01, dtype: flo...
# Apr  CHIC917URN    6.3
# Name: 1990-04-01, dtype: flo...
# May  CHIC917URN    6.1
# Name: 1990-05-01, dtype: flo...
# Jun  CHIC917URN    6.2
# Name: 1990-06-01, dtype: flo...
# Jul  CHIC917URN    6.3
# Name: 1990-07-01, dtype: flo...
# Aug  CHIC917URN    6.4
# Name: 1990-08-01, dtype: flo...
# Sep  CHIC917URN    6.3
# Name: 1990-09-01, dtype: flo...
# Oct  CHIC917URN    6.0
# Name: 1990-10-01, dtype: flo...
# Nov  CHIC917URN    5.9
# Name: 1990-11-01, dtype: flo...
# Dec  CHIC917URN    6.2
# Name: 1990-12-01, dtype: flo...
#
#                           Unemployment_National
# Jan  UNRATE    4.0
# Name: 1/1/00, dtype: float64
# Feb  UNRATE    4.2
# Name: 1/1/01, dtype: float64
# Mar  UNRATE    5.7
# Name: 1/1/02, dtype: float64
# Apr  UNRATE    5.8
# Name: 1/1/03, dtype: float64
# May  UNRATE    5.7
# Name: 1/1/04, dtype: float64
# Jun  UNRATE    5.3
# Name: 1/1/05, dtype: float64
# Jul  UNRATE    4.7
# Name: 1/1/06, dtype: float64
# Aug  UNRATE    4.6
# Name: 1/1/07, dtype: float64
# Sep  UNRATE    5.0
# Name: 1/1/08, dtype: float64
# Oct  UNRATE    7.8
# Name: 1/1/09, dtype: float64
# Nov  UNRATE    9.8
# Name: 1/1/10, dtype: float64
# Dec  UNRATE    9.1
# Name: 1/1/11, dtype: float64

# %%
x = Population.index.tolist()
y1 = Population['Unemployment_Average'].tolist()
y2 = Population['Unemployment_National'].tolist()

plt.plot(x, y1, '-s', label = "Chicago unemployment")
plt.plot(x, y2, '-*', label = "National Unemployment")
plt.title('Unemployment in the Chicago Metropolitan Area and in the World per month.')
plt.legend(frameon = False)
[plt.gca().spines[loc].set_visible(False) for loc in ['top', 'right']]

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
